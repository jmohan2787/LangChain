# %%
import os
from langchain.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv

# %%
load_dotenv(dotenv_path='.env')
# Out:
# True

# %%
llm=ChatOpenAI(model='gpt-3.5-turbo', temperature=0)

# %%
prompt=PromptTemplate.from_template('Answer clarly:{question}')

# %%
qa_chain=LLMChain(llm=llm,prompt=prompt)

# %%
query='what is LangGraph?'
response=qa_chain.run({'question': query})

# %%
print('\nUser input:', query)
print('\nLLM Answer:',response)
# Out:
# User input: what is LangGraph?
#
# LLM Answer: LangGraph is a graph-based language model that uses graph structures to represent and analyze natural language text. It is used for tasks such as text generation, summarization, and sentiment analysis.
