# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
import os
from dotenv import load_dotenv
from langchain.agents import Tool

# %%
load_dotenv(dotenv_path='.env')
# Out:
# True

# %%
llm=ChatOpenAI(model='gpt-3.5-turbo',temperature=0)

# %%
prompt=PromptTemplate.from_template("Answer clearly: {question}")

# %%
qa_chain=LLMChain(llm=llm,prompt=prompt)

# %%
qa_tools=Tool(name='Simple QA',func=qa_chain.run, description="A basic LLM chain to answer clear questions")

# %%
query='what is LangGraph, explain me?'
answer=qa_tools.run(query)

# %%
print('\n User Question:', query)
print('\n LLM Answers:', answer)
# Out:
#  User Question: what is LangGraph, explain me?
#
#  LLM Answers: LangGraph is a tool used for visualizing and analyzing the relationships between languages. It allows users to create graphs that show how languages are related to each other through factors such as historical connections, linguistic similarities, and geographical proximity. This can help researchers and linguists better understand the evolution and distribution of languages over time.
