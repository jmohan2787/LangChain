# %% [markdown]
# | **Memory ↓ / Agent →**              | **Conversational Agent**             | **ZERO_SHOT_REACT_DESCRIPTION**     | **STRUCTURED_CHAT_ZERO_SHOT_REACT_DESCRIPTION** | **SELF_ASK_WITH_SEARCH**          | **OPENAI_FUNCTIONS**                             | **OPENAI_MULTI_FUNCTIONS**            | **Tool-Using Agent**                              | **RAG Agent**                   | **Planning Agent**                         | **Multi-Agent System**                           |
# | ----------------------------------- | ------------------------------------ | ----------------------------------- | ----------------------------------------------- | --------------------------------- | ------------------------------------------------ | ------------------------------------- | ------------------------------------------------- | ------------------------------- | ------------------------------------------ | ------------------------------------------------ |
# | **ConversationBufferMemory**        | ✔️ Natural chat                      | ⚠️ Can confuse ReAct chain          | ⚠️ Structured ReAct also gets noisy             | ❌ Not needed                      | ⚠️ Not recommended; functions need clean input   | ⚠️ Same issue as above                | ⚠️ Prompt becomes too big                         | ❌ RAG does NOT use chat memory  | ⚠️ Summaries are better                    | ❌ Not shareable                                  |
# | **ConversationBufferWindowMemory**  | ✔️ Best lightweight chat             | ✔️ Good for ReAct with short window | ✔️ Good for structured ReAct                    | ❌ No need for memory              | ✔️ Keeps function calls clean                    | ✔️ Helps multi-functions stay short   | ✔️ Ideal for tool loops                           | ❌ RAG doesn't need chat history | ⚠️ Limited memory                          | ❌ Window memory cannot be shared                 |
# | **ConversationTokenBufferMemory**   | ✔️ Best for long chats               | ✔️ Best memory for ReAct reasoning  | ✔️ Best for structured ReAct                    | ❌ No chat needed                  | ✔️ Great for tokens-aware function calls         | ✔️ Great for multi-function calls     | ✔️ Ideal for tool-heavy interaction               | ❌ RAG doesn't use chat memory   | ⚠️ Useful but limited                      | ❌ Not shareable                                  |
# | **ConversationSummaryMemory**       | ✔️ Strong for long-running chat      | ⚠️ Summaries hide reasoning steps   | ⚠️ Can distort structured prompts               | ❌ No need                         | ⚠️ Summaries may break function-calling          | ⚠️ Same issue as above                | ⚠️ Tools need original data                       | ❌ Not used in RAG               | ✔️ Good: reduces tokens                    | ⚠️ Not ideal                                     |
# | **ConversationSummaryBufferMemory** | ✔️ Best for chat + short history     | ✔️ Balanced for ReAct               | ✔️ Balanced for structured ReAct                | ❌ Not needed                      | ⚠️ Summaries may affect function calls           | ⚠️ Same issue as above                | ✔️ Recently useful                                | ❌ Not used in RAG               | ✔️ Very good for planning                  | ⚠️ Not shared                                    |
# | **VectorStoreRetrieverMemory**      | ⚠️ Overkill for simple chat          | ✔️ Good for ReAct referencing docs  | ✔️ Good for structured ReAct referencing docs   | ✔️ Excellent: query decomposition | ✔️ Useful when functions rely on prior knowledge | ✔️ Great for multi-functions          | ✔️ Great for tool agents needing knowledge search | ✔️ **PRIMARY MEMORY FOR RAG**   | ✔️ Structured long-term memory             | ⚠️ Must avoid write conflicts                    |
# | **EntityMemory**                    | ✔️ Best for remembering user details | ⚠️ ReAct rarely uses entities       | ⚠️ Structured agents may overfit entities       | ❌ Not suited                      | ✔️ Great for personal assistant functions        | ✔️ Useful for multi-function chatbots | ✔️ Tool agents often need entity memory           | ❌ RAG doesn't use entities      | ✔️ Good for planning around people/objects | ⚠️ Conflicts in multi-agent                      |
# | **ReadOnlySharedMemory**            | ❌ Not needed                         | ❌ ReAct needs writable scratchpad   | ❌ Structured ReAct needs writable memory        | ❌ No use                          | ⚠️ Rare use                                      | ✔️ Useful for shared function context | ⚠️ Limited                                        | ❌ RAG uses RetrieverMemory      | ✔️ Very useful                             | ✔️ **Best for multi-agent systems**              |
# | **MotorheadMemory**                 | ✔️ For extremely long chats          | ✔️ Stores very long ReAct traces    | ✔️ Stores structured ReAct data                 | ✔️ Helps long query decomposition | ✔️ Great for logging long function histories     | ✔️ Handles multi-functions with trace | ✔️ Supports heavy tool usage                      | ⚠️ Overkill for RAG             | ✔️ Great for long-term planning            | ✔️ Best when multiple agents use external memory |

# %% [markdown]
# | **Memory Type ↓ / Agent Type →**    | **Conversational Agent**                           | **ReAct Agent**                            | **Tool-Using Agent**                              | **RAG Agent**                           | **Planning Agent**                  | **Multi-Agent System**                      |
# | ----------------------------------- | -------------------------------------------------- | ------------------------------------------ | ------------------------------------------------- | --------------------------------------- | ----------------------------------- | ------------------------------------------- |
# | **ConversationBufferMemory**        | ✔️ Natural chat context                            | ⚠️ Too large context may confuse reasoning | ⚠️ Works but prompt may overflow                  | ❌ RAG uses retrievers instead           | ⚠️ Long context not ideal           | ❌ Each agent should not share full history  |
# | **ConversationBufferWindowMemory**  | ✔️ Lightweight chatbots                            | ✔️ Better for reasoning steps              | ✔️ Good for tool-calling loops                    | ❌ Not used in retrieval workflows       | ⚠️ Limited long memory              | ❌ Window memory is not shareable            |
# | **ConversationTokenBufferMemory**   | ✔️ Best for long chats with token limits           | ✔️ Great for ReAct (keeps prompts small)   | ✔️ Ideal for agents using multiple tools          | ❌ RAG does not benefit from chat memory | ⚠️ Useful but still limited         | ❌ Token memory cannot be shared             |
# | **ConversationSummaryMemory**       | ✔️ Good for long-running sessions                  | ⚠️ Summaries may hide key reasoning info   | ⚠️ Tools may need exact past details              | ❌ Retrieval > Summary for RAG           | ✔️ Very useful for long planning    | ⚠️ Not shareable memory                     |
# | **ConversationSummaryBufferMemory** | ✔️ Best for chatbots & voice agents                | ✔️ Balance of summary + recent steps       | ✔️ Good for tool agents needing context + recency | ❌ RAG relies on VectorStore             | ✔️ Good context for planning        | ⚠️ Still not shared memory                  |
# | **VectorStoreRetrieverMemory**      | ⚠️ Only needed if chatbot requires semantic recall | ✔️ Helpful when reasoning from long docs   | ✔️ Great when tools require document lookups      | ✔️ **The primary memory type for RAG**  | ✔️ Stores long-term structured info | ⚠️ Agents must not overwrite shared vectors |
# | **ReadOnlySharedMemory**            | ❌ Not needed                                       | ⚠️ Rare use                                | ⚠️ Sometimes useful                               | ⚠️ Use only for shared knowledge        | ✔️ Good for multi-step planners     | ✔️ **The best for multi-agent systems**     |
# | **EntityMemory**                    | ✔️ Best for remembering user-specific facts        | ⚠️ ReAct doesn’t need entity tracking      | ✔️ Useful when tools need user/entity data        | ❌ Not for RAG                           | ✔️ Helps planners track entities    | ⚠️ Could conflict in multi-agent scenario   |
# | **MotorheadMemory**                 | ✔️ For extremely long conversations                | ✔️ Helps store very long ReAct traces      | ✔️ Supports heavy tool usage                      | ⚠️ Overkill for RAG                     | ✔️ Great for long-term memory tasks | ✔️ Distributed memory for teams             |
